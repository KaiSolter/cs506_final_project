# %% [markdown]
# Importing necessary data analysis/processing tools

# %%
import os
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# Loading our dataset into a Dataframe `df`.

# %%
df = pd.read_csv('allfeaturesfinal.csv', header = 0)

# %% [markdown]
# Inspecting the Data we collected

# %% [markdown]
# 1) Size of our dataset
# 2) Displaying our column names
# 3) Display first few rows of our data

# %%
print(df.shape)
print(df.columns)
df.head(10)
# Out:
# (3223, 47)
# Index(['user_id', 'user_black_draw_rate', 'user_black_game_count',
#        'user_black_lose_rate', 'user_black_win_rate', 'user_blitz_rating',
#        'user_draw_rate', 'user_game_count',
#        'user_highest_blitz_opponent_rating', 'user_lose_rate',
#        'user_loss_streak_current', 'user_loss_streak_max',
#        'user_rating_deviation', 'user_second_highest_blitz_opponent_rating',
#        'user_third_highest_blitz_opponent_rating', 'user_total_games_played',
#        'user_white_draw_rate', 'user_white_game_count', 'user_white_lose_rate',
#        'user_white_win_rate', 'user_win_rate', 'user_win_streak_current',
#        'user_win_streak_max', 'user_op', 'op_black_draw_rate',
#        'op_black_game_count', 'op_black_lose_rate', 'op_black_win_rate',
#        'op_blitz_rating', 'op_draw_rate', 'op_game_count',
#        'op_highest_blitz_opponent_rating', 'op_lose_rate',
#        'op_loss_streak_current', 'op_loss_streak_max', 'op_rating_deviation',
#        'op_second_highest_blitz_opponent_rating',
#        'op_third_highest_blitz_opponent_rating', 'op_total_games_played',
#        'op_white_draw_rate', 'op_white_game_count', 'op_white_lose_rate',
#        'op_white_win_rate', 'op_win_rate', 'op_win_streak_current',
#        'op_win_streak_max', 'game_result'],
#       dtype='object')
#             user_id  user_black_draw_rate  user_black_game_count  \
# 0       engsultan00              0.000000                   48.0
# 1             Panfi              3.846154                   52.0
# 2             rsk86              4.166667                   48.0
# 3          mercanet              4.000000                   50.0
# 4     cool-chess-21              9.803922                   51.0
# 5     bhavyamarella              4.545455                   44.0
# 6       cironine999              6.000000                   50.0
# 7  chessenthusiast2              0.000000                   51.0
# 8         derwolf21             10.204082                   49.0
# 9       mmchess2023              0.000000                   47.0
#
#    user_black_lose_rate  user_black_win_rate  user_blitz_rating  \
# 0             47.916667            52.083333             1768.0
# 1             55.769231            40.384615             1351.0
# 2             58.333333            37.500000             1460.0
# 3             52.000000            44.000000             1743.0
# 4             37.254902            52.941176             1690.0
# 5             56.818182            38.636364             1016.0
# 6             56.000000            38.000000             1785.0
# 7             43.137255            56.862745             1439.0
# 8             53.061224            36.734694             1705.0
# 9             42.553191            57.446809             1308.0
#
#    user_draw_rate  user_game_count  user_highest_blitz_opponent_rating  \
# 0             1.0            100.0                              2221.0
# 1             5.0            100.0                              1557.0
# 2             7.0            100.0                              1574.0
# 3             3.0            100.0                              1922.0
# 4             0.0              9.0                              1993.0
# 5             0.0             12.0                              1644.0
# 6             7.0            100.0                              2220.0
# 7             1.0            100.0                              1837.0
# 8             6.0            100.0                              2043.0
# 9             0.0             57.0                              1427.0
#
#    user_lose_rate  ...  op_third_highest_blitz_opponent_rating  \
# 0            49.0  ...                                  1952.0
# 1            49.0  ...                                     NaN
# 2            43.0  ...                                  1752.0
# 3            50.0  ...                                  1901.0
# 4            66.0  ...                                  1305.0
# 5            75.0  ...                                  1180.0
# 6            52.0  ...                                  1949.0
# 7            46.0  ...                                  1693.0
# 8            53.0  ...                                  2027.0
# 9            63.0  ...                                  1787.0
#
#    op_total_games_played  op_white_draw_rate  op_white_game_count  \
# 0                    526            0.000000                 49.0
# 1                      4            0.000000                  0.0
# 2                   4784            2.040816                 49.0
# 3                   6852            4.166667                 48.0
# 4                     89            4.444444                 45.0
# 5                    462            8.163265                 49.0
# 6                    107            4.081633                 49.0
# 7                  11017            2.000000                 50.0
# 8                   2387            4.081633                 49.0
# 9                     16           25.000000                  8.0
#
#    op_white_lose_rate  op_white_win_rate  op_win_rate  op_win_streak_current  \
# 0           53.061224          46.938776         40.0                    2.0
# 1            0.000000           0.000000          0.0                    0.0
# 2           53.061224          44.897959         45.0                    2.0
# 3           39.583333          56.250000         49.0                    0.0
# 4           53.333333          42.222222          0.0                    0.0
# 5           44.897959          46.938776         48.0                    0.0
# 6           20.408163          75.510204         62.0                    3.0
# 7           46.000000          52.000000         48.0                    1.0
# 8           42.857143          53.061224         41.0                    2.0
# 9           37.500000          37.500000          0.0                    2.0
#
#    op_win_streak_max  game_result
# 0                8.0            0
# 1                1.0            1
# 2               12.0            1
# 3               22.0           -1
# 4                6.0           -1
# 5                5.0           -1
# 6                9.0            1
# 7               11.0            1
# 8                9.0            1
# 9                2.0            1
#
# [10 rows x 47 columns]

# %% [markdown]
# Identifying missingness: If we have 0 in game_count for a user, we have missing values and should drop it

# %%
zero_count = (df == 0).sum()
zero_count
# Out:
# user_id                                         0
# user_black_draw_rate                          543
# user_black_game_count                          11
# user_black_lose_rate                           15
# user_black_win_rate                            36
# user_blitz_rating                               0
# user_draw_rate                                528
# user_game_count                                 0
# user_highest_blitz_opponent_rating              0
# user_lose_rate                                 40
# user_loss_streak_current                     1472
# user_loss_streak_max                            9
# user_rating_deviation                          32
# user_second_highest_blitz_opponent_rating       0
# user_third_highest_blitz_opponent_rating        0
# user_total_games_played                        12
# user_white_draw_rate                          581
# user_white_game_count                           6
# user_white_lose_rate                           15
# user_white_win_rate                            27
# user_win_rate                                  75
# user_win_streak_current                      1881
# user_win_streak_max                            22
# user_op                                         0
# op_black_draw_rate                            645
# op_black_game_count                           102
# op_black_lose_rate                            113
# op_black_win_rate                             138
# op_blitz_rating                                 0
# op_draw_rate                                  823
# op_game_count                                 437
# op_highest_blitz_opponent_rating                0
# op_lose_rate                                  466
# op_loss_streak_current                       1642
# op_loss_streak_max                             93
# op_rating_deviation                            33
# op_second_highest_blitz_opponent_rating         0
# op_third_highest_blitz_opponent_rating          0
# op_total_games_played                         110
# op_white_draw_rate                            676
# op_white_game_count                            99
# op_white_lose_rate                            111
# op_white_win_rate                             140
# op_win_rate                                   495
# op_win_streak_current                        1781
# op_win_streak_max                             117
# game_result                                   119
# dtype: int64

# %% [markdown]
# We can see that there are many fields that contain 0 values. For some columns, we know that having a significant number of 0 values in their columns is a bad sign. We should drop some of the rows containing the these values.
